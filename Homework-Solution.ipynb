# %%
# importing all necessary libraries
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading the dataset
data = pd.read_csv('data.csv')
data.shape
# Out:
# (18207, 89)

# %%
# lets also check the columns in the data
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %% [markdown]
# ### Find the Most Expensive Players whose contracts are going to Expire Soon

# %%
x
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 3               3  193080              De Gea   27
# 5               5  183277           E. Hazard   27
# 6               6  177003           L. Modrić   32
# 8               8  155862        Sergio Ramos   32
# 13             13  168542         David Silva   32
# ...           ...     ...                 ...  ...
# 18166       18166  243621            N. Ayéva   16
# 18179       18179  246243         J. Williams   17
# 18187       18187  240158           C. Ehlich   19
# 18189       18189  240160          A. Kaltner   18
# 18203       18203  243165  N. Christoffersson   19
#
#                                                 Photo Nationality  \
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 5      https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# 6      https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 8      https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 13     https://cdn.sofifa.org/players/4/19/168542.png       Spain
# ...                                               ...         ...
# 18166  https://cdn.sofifa.org/players/4/19/243621.png      Sweden
# 18179  https://cdn.sofifa.org/players/4/19/246243.png     England
# 18187  https://cdn.sofifa.org/players/4/19/240158.png     Germany
# 18189  https://cdn.sofifa.org/players/4/19/240160.png     Germany
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
#
#                                       Flag  Overall  Potential  \
# 3      https://cdn.sofifa.org/flags/45.png       91         93
# 5       https://cdn.sofifa.org/flags/7.png       91         91
# 6      https://cdn.sofifa.org/flags/10.png       91         91
# 8      https://cdn.sofifa.org/flags/45.png       91         91
# 13     https://cdn.sofifa.org/flags/45.png       90         90
# ...                                    ...      ...        ...
# 18166  https://cdn.sofifa.org/flags/46.png       48         72
# 18179  https://cdn.sofifa.org/flags/14.png       48         64
# 18187  https://cdn.sofifa.org/flags/21.png       47         59
# 18189  https://cdn.sofifa.org/flags/21.png       47         61
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
#
#                      Club  ... Composure Marking  StandingTackle  \
# 3       Manchester United  ...      68.0    15.0            21.0
# 5                 Chelsea  ...      91.0    34.0            27.0
# 6             Real Madrid  ...      84.0    60.0            76.0
# 8             Real Madrid  ...      82.0    87.0            92.0
# 13        Manchester City  ...      93.0    59.0            53.0
# ...                   ...  ...       ...     ...             ...
# 18166           Örebro SK  ...      44.0    14.0            19.0
# 18179    Northampton Town  ...      37.0    42.0            51.0
# 18187  SpVgg Unterhaching  ...      47.0    40.0            42.0
# 18189  SpVgg Unterhaching  ...      37.0    28.0            15.0
# 18203      Trelleborgs FF  ...      42.0    22.0            15.0
#
#        SlidingTackle GKDiving  GKHandling  GKKicking  GKPositioning  \
# 3               13.0     90.0        85.0       87.0           88.0
# 5               22.0     11.0        12.0        6.0            8.0
# 6               73.0     13.0         9.0        7.0           14.0
# 8               91.0     11.0         8.0        9.0            7.0
# 13              29.0      6.0        15.0        7.0            6.0
# ...              ...      ...         ...        ...            ...
# 18166           16.0     10.0         9.0        8.0            7.0
# 18179           49.0     14.0        11.0        7.0           11.0
# 18187           42.0     13.0        12.0       11.0           15.0
# 18189           22.0     15.0         5.0       14.0           12.0
# 18203           19.0     10.0         9.0        9.0            5.0
#
#       GKReflexes Release Clause
# 3           94.0        €138.6M
# 5            8.0        €172.1M
# 6            9.0        €137.4M
# 8           11.0        €104.6M
# 13          12.0          €111M
# ...          ...            ...
# 18166        6.0          €158K
# 18179        8.0          €119K
# 18187       12.0           €66K
# 18189        8.0          €125K
# 18203       12.0          €113K
#
# [4027 rows x 89 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

# we have to filter players whose contracts are going to be valid till 2020 only.
x = data[data['Contract Valid Until'] == "2020"]

# defining a function for cleaning the wage column
def extract_value_from(column):
    out = column.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in column:
        out = float(out.replace('K', ''))*1000
    return float(out)

# applying the function to the wage column so that we can sort the highest paid footballers
x['Wage'] = x['Wage'].apply(extract_value_from)

# Now we have to sort those players who are highest paid
x[['Name','Nationality','Club','Age', 'Wage']].sort_values(by = 'Wage', ascending = False).head(10)
# Out:
#             Name Nationality                 Club  Age      Wage
# 6      L. Modrić     Croatia          Real Madrid   32  420000.0
# 8   Sergio Ramos       Spain          Real Madrid   32  380000.0
# 5      E. Hazard     Belgium              Chelsea   27  340000.0
# 13   David Silva       Spain      Manchester City   32  285000.0
# 3         De Gea       Spain    Manchester United   27  260000.0
# 49    Jordi Alba       Spain         FC Barcelona   29  250000.0
# 24  G. Chiellini       Italy             Juventus   33  215000.0
# 31    C. Eriksen     Denmark    Tottenham Hotspur   26  205000.0
# 21     E. Cavani     Uruguay  Paris Saint-Germain   31  200000.0
# 46      K. Navas  Costa Rica          Real Madrid   31  195000.0

# %% [markdown]
# ### Make a Function to Generate a Report for Players

# %%
def report(player):
    return data[data['Name'] == player][['Nationality','Club',
                                         'Overall','Potential',
                                         'Contract Valid Until','Wage',
                                        'International Reputation']].reset_index(drop = True).T

report('L. Messi')
# Out:
#                                      0
# Nationality                  Argentina
# Club                      FC Barcelona
# Overall                             94
# Potential                           94
# Contract Valid Until              2021
# Wage                             €565K
# International Reputation             5

# %% [markdown]
# ### Compare Indian Footballers with Russian Footballers

# %%
x
# Out:
#        Unnamed: 0      ID             Name  Age  \
# 276           276  193525  Mário Fernandes   27
# 381           381  187491        F. Smolov   28
# 541           541  148119      I. Akinfeev   32
# 542           542  147782       I. Denisov   34
# 568           568  229909         A. Lunev   26
# ...           ...     ...              ...  ...
# 17129       17129  228198         J. Singh   26
# 17197       17197  245164         V. Kaith   21
# 17339       17339  233526         S. Passi   23
# 17436       17436  236452   D. Lalhlimpuia   20
# 17539       17539  234508         C. Singh   21
#
#                                                 Photo Nationality  \
# 276    https://cdn.sofifa.org/players/4/19/193525.png      Russia
# 381    https://cdn.sofifa.org/players/4/19/187491.png      Russia
# 541    https://cdn.sofifa.org/players/4/19/148119.png      Russia
# 542    https://cdn.sofifa.org/players/4/19/147782.png      Russia
# 568    https://cdn.sofifa.org/players/4/19/229909.png      Russia
# ...                                               ...         ...
# 17129  https://cdn.sofifa.org/players/4/19/228198.png       India
# 17197  https://cdn.sofifa.org/players/4/19/245164.png       India
# 17339  https://cdn.sofifa.org/players/4/19/233526.png       India
# 17436  https://cdn.sofifa.org/players/4/19/236452.png       India
# 17539  https://cdn.sofifa.org/players/4/19/234508.png       India
#
#                                        Flag  Overall  Potential  \
# 276     https://cdn.sofifa.org/flags/40.png       82         82
# 381     https://cdn.sofifa.org/flags/40.png       81         81
# 541     https://cdn.sofifa.org/flags/40.png       80         80
# 542     https://cdn.sofifa.org/flags/40.png       80         80
# 568     https://cdn.sofifa.org/flags/40.png       79         81
# ...                                     ...      ...        ...
# 17129  https://cdn.sofifa.org/flags/159.png       55         58
# 17197  https://cdn.sofifa.org/flags/159.png       55         64
# 17339  https://cdn.sofifa.org/flags/159.png       54         63
# 17436  https://cdn.sofifa.org/flags/159.png       54         67
# 17539  https://cdn.sofifa.org/flags/159.png       53         62
#
#                    Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 276     PFC CSKA Moscow  ...      76.0    83.0           82.0           84.0
# 381    Lokomotiv Moscow  ...      73.0    26.0           28.0           24.0
# 541     PFC CSKA Moscow  ...      67.0    18.0           13.0           13.0
# 542    Lokomotiv Moscow  ...      77.0    81.0           81.0           73.0
# 568                 NaN  ...      69.0    18.0           20.0           12.0
# ...                 ...  ...       ...     ...            ...            ...
# 17129               NaN  ...      42.0    26.0           18.0           13.0
# 17197               NaN  ...      29.0     8.0           12.0           11.0
# 17339               NaN  ...      45.0    14.0           23.0           21.0
# 17436               NaN  ...      46.0    26.0           17.0           13.0
# 17539               NaN  ...      41.0    56.0           49.0           53.0
#
#       GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 276       12.0        13.0       14.0           13.0       12.0         €40.7M
# 381       16.0         9.0       16.0           15.0       10.0         €38.9M
# 541       77.0        72.0       78.0           82.0       84.0         €18.7M
# 542       13.0         7.0       15.0           13.0       12.0          €9.4M
# 568       80.0        73.0       65.0           77.0       85.0            NaN
# ...        ...         ...        ...            ...        ...            ...
# 17129     15.0        14.0        8.0           10.0       16.0            NaN
# 17197     55.0        50.0       57.0           59.0       53.0            NaN
# 17339      8.0         6.0       13.0            9.0       10.0            NaN
# 17436      7.0         8.0       12.0           11.0       11.0            NaN
# 17539     12.0         9.0        6.0           14.0        8.0            NaN
#
# [109 rows x 89 columns]

# %%
# lets first filter all the Russian and Indian Footballers
x = data[(data['Nationality'] == 'Russia') | (data['Nationality'] == 'India')]

# now let's group this datasets based on nationality and aggregate on Potential and Overall Scores
x[['Nationality','Overall','Potential']].groupby(['Nationality']).agg('mean').style.background_gradient(cmap = 'copper')
# Out:
# <style  type="text/css" >
#     #T_2beb40d5_1777_11ec_8d08_3ca067fee778row0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_2beb40d5_1777_11ec_8d08_3ca067fee778row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_2beb40d5_1777_11ec_8d08_3ca067fee778row1_col0 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_2beb40d5_1777_11ec_8d08_3ca067fee778row1_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }</style><table id="T_2beb40d5_1777_11ec_8d08_3ca067fee778" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Overall</th>        <th class="col_heading level0 col1" >Potential</th>    </tr>    <tr>        <th class="index_name level0" >Nationality</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2beb40d5_1777_11ec_8d08_3ca067fee778level0_row0" class="row_heading level0 row0" >India</th>
#                         <td id="T_2beb40d5_1777_11ec_8d08_3ca067fee778row0_col0" class="data row0 col0" >58.666667</td>
#                         <td id="T_2beb40d5_1777_11ec_8d08_3ca067fee778row0_col1" class="data row0 col1" >63.600000</td>
#             </tr>
#             <tr>
#                         <th id="T_2beb40d5_1777_11ec_8d08_3ca067fee778level0_row1" class="row_heading level0 row1" >Russia</th>
#                         <td id="T_2beb40d5_1777_11ec_8d08_3ca067fee778row1_col0" class="data row1 col0" >70.063291</td>
#                         <td id="T_2beb40d5_1777_11ec_8d08_3ca067fee778row1_col1" class="data row1 col1" >75.341772</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Find the Most Popular Footballers under 20

# %%
# lets first filter all the under 20 players and then sort with their Values

x = data[data['Age'] < 20]

# defining a function for cleaning the wage column
def extract_value_from(column):
    out = column.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in column:
        out = float(out.replace('K', ''))*1000
    return float(out)

# applying the function to the wage column so that we can sort the highest paid footballers
x['Value'] = x['Value'].apply(extract_value_from)

x[['Name','Age','Value','Overall']].sort_values(by = 'Value', ascending = True).head(10).style.background_gradient(cmap = 'copper')
# Out:
# <style  type="text/css" >
#     #T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col3 {
#             background-color:  #c87f51;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col3 {
#             background-color:  #ffa368;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col3 {
#             background-color:  #9e6440;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col3 {
#             background-color:  #553622;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col3 {
#             background-color:  #553622;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row5_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row5_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row5_col3 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row6_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row6_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row6_col3 {
#             background-color:  #805134;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row7_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row7_col2 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row7_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row8_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row8_col2 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row8_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row9_col1 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row9_col2 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_d696bde2_1777_11ec_8aaa_3ca067fee778row9_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_d696bde2_1777_11ec_8aaa_3ca067fee778" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Age</th>        <th class="col_heading level0 col2" >Value</th>        <th class="col_heading level0 col3" >Overall</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d696bde2_1777_11ec_8aaa_3ca067fee778level0_row0" class="row_heading level0 row0" >11470</th>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col0" class="data row0 col0" >N. Ferraresi</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col1" class="data row0 col1" >19</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col2" class="data row0 col2" >0.000000</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row0_col3" class="data row0 col3" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_d696bde2_1777_11ec_8aaa_3ca067fee778level0_row1" class="row_heading level0 row1" >6639</th>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col0" class="data row1 col0" >I. Hagi</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col1" class="data row1 col1" >19</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col2" class="data row1 col2" >0.000000</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row1_col3" class="data row1 col3" >68</td>
#             </tr>
#             <tr>
#                         <th id="T_d696bde2_1777_11ec_8aaa_3ca067fee778level0_row2" class="row_heading level0 row2" >14124</th>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col0" class="data row2 col0" >A. Paşcanu</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col1" class="data row2 col1" >19</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col2" class="data row2 col2" >0.000000</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row2_col3" class="data row2 col3" >61</td>
#             </tr>
#             <tr>
#                         <th id="T_d696bde2_1777_11ec_8aaa_3ca067fee778level0_row3" class="row_heading level0 row3" >16903</th>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col0" class="data row3 col0" >J. Lalrinzuala</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col1" class="data row3 col1" >19</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col2" class="data row3 col2" >0.000000</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row3_col3" class="data row3 col3" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_d696bde2_1777_11ec_8aaa_3ca067fee778level0_row4" class="row_heading level0 row4" >16783</th>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col0" class="data row4 col0" >M. Smith</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col1" class="data row4 col1" >18</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col2" class="data row4 col2" >0.000000</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row4_col3" class="data row4 col3" >56</td>
#             </tr>
#             <tr>
#                         <th id="T_d696bde2_1777_11ec_8aaa_3ca067fee778level0_row5" class="row_heading level0 row5" >3562</th>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row5_col0" class="data row5 col0" >B. Méndez</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row5_col1" class="data row5 col1" >18</td>
#                         <td id="T_d696bde2_1777_11ec_8aaa_3ca067fee778row5_col2" class="data row5 col2" >0
